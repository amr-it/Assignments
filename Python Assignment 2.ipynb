# %% [markdown]
# 1.What are the two values of the Boolean data type? How do you write them?
#
# The 2 values of Boolean data type are True and False.
#
# For example, a = True will assign True value to the variable a.
#
# 2. What are the three different types of Boolean operators?
#
# The 3 different types of Boolean operators are AND, OR & NOT.
#
# AND checks if all conditions are satisifed
# OR checks if one of all conditions is satisfied
# NOT checks if condition given is false

# %% [raw]
# 3. Make a list of each Boolean operator's truth tables (i.e. every possible combination of Boolean
# values for the operator and what it evaluate ).
#
# AND Truth Table
# x 	    and 	y 	    Returns
# True 	and 	True 	True
# True 	and 	False 	False
# False 	and 	True 	False
# False 	and 	False 	False
#
# OR Truth Table
# x 	    and 	y 	    Returns
# True 	or  	True 	True
# True 	or  	False 	True
# False 	or  	True 	True
# False 	or  	False 	False
#
# NOT Truth Table
# not 	x   	Returns
# not 	False 	True
# not 	True   	False

# %% [markdown]
# 4. What are the values of the following expressions?
#
# (5 > 4) and (3 == 5)                    False
# not (5 > 4)                             False
# (5 > 4) or (3 == 5)                     True
# not ((5 > 4) or (3 == 5))               False
# (True and True) and (True == False)     False
# (not False) or (not True)               True
#
# 5. What are the six comparison operators?
#
# They are == , != , < , > , <=  and >=
#
# 6. How do you tell the difference between the equal to and assignment operators? Describe a condition and when you would use one.
#
# == is used to check whether 2 operands are equal or not. For example, 3==4 will return false, as 3 is not equal to 4.
# = is used to assign value on right to value on left. For example, a=3 will assign 3 to variable a.
#
# 7. Identify the three blocks in this code:
# spam = 0
# if spam == 10:
#     print('eggs')
# if spam > 5:
#     print('bacon')
# else:
#     print('ham')
#     print('spam')
#     print('spam')
#
# 1st Block is spam = 0, where you declare a variable and assign it value of 0
# 2nd Block is if spam == 10 and print, where you check spam's value and based on it, print a value.
# 3rd Block is if-else block.
#
# 8. Write code that prints Hello if 1 is stored in spam, prints Howdy if 2 is stored in spam, and prints Greetings! if anything else is stored in spam.
#
# spam = input("Enter Value for spam")
# if spam == str(1):
#     print('Hello')
# elif spam == str(2):
#     print('Howdy')
# else:
#     print('Greetings!')
#
# 9. If your programme is stuck in an endless loop, what keys you’ll press?
#
# You can stop an infinite loop with CTRL + C . You can generate an infinite loop intentionally with while True . The break statement can be used to stop a while loop immediately.
#
# 10. How can you tell the difference between break and continue?
#
# The main difference between both the statements is that when break keyword comes, it terminates the execution of the current loop and passes the control over the next loop or main body, whereas when continue keyword is encountered, it skips the current iteration and executes the very next iteration in the loop.
#
# 11. In a for loop, what is the difference between range(10), range(0, 10), and range(0, 10, 1)?
#
# range(10) returns a sequence of numbers from 0 to 9.
# range(0,10) returns a sequence of numbers from 0 to 9.
# range(0,10,1) returns a sequence of numbers from 0 to 9.
#
# 12. Write a short program that prints the numbers 1 to 10 using a for loop. Then write an equivalent program that prints the numbers 1 to 10 using a while loop.
#
# for i in range(0,10,1):
#     print(i)
#
# a=0
# while(a<10):
#     print(a)
#     a=a+1
#
# 13. If you had a function named bacon() inside a module named spam, how would you call it after importing spam?
#
# from spam import *
# bacon()
